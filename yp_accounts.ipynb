# %%
import pandas as pd
import matplotlib as plt
import bank_account
from random import randrange

# %%
def create_accounts (num_accounts):
    """
    Method to create a specified number of accounts and store them in all_accounts dict.
    :param num_accounts: number of accounts to create
    :return: dict containing the generated accounts
    """

    all_accounts = {}

    for i in range (num_accounts):
        # Generate accounts with accounts with random ranges of values
        created_account = {}

        created_account["ID"] = i
        created_account["Profile"] = "young professional"
        created_account["Balance"] = randrange(5000, 15000)
        created_account["Income"] = randrange(4000, 8000)
        created_account["Rent"] = randrange(800, 1200)
        created_account["Groceries"] = randrange(200, 600)
        created_account["Transportation"] = randrange(150, 350)
        created_account["Medical"] = randrange(100, 300)
        created_account["Entertainment"] = randrange(100, 300)
        created_account["Shopping"] = randrange(100, 300)
        created_account["Dining"] = randrange(200, 400)
        created_account["Total Expenditures"] = created_account["Balance"] + created_account["Income"]\
                                                + created_account["Income"] + created_account["Rent"] \
                                                + created_account["Groceries"] + created_account["Transportation"]\
                                                + created_account["Medical"] + created_account["Entertainment"]\
                                                + created_account["Shopping"] + created_account["Dining"]

        all_accounts[str(i)] = created_account # Increment ID

    return all_accounts

# %%
data = create_accounts(100)

# %%
pd.DataFrame.from_dict(data, orient='index')
# Out:
#                Profile  Transportation  Total Expenditures  Entertainment  \
# 0   young professional             336               26363            118
# 1   young professional             329               26914            108
# 10  young professional             293               23219            107
# 11  young professional             220               20323            260
# 12  young professional             277               23651            131
# 13  young professional             183               22137            139
# 14  young professional             164               17348            192
# 15  young professional             316               20831            157
# 16  young professional             153               19988            282
# 17  young professional             190               25354            232
# 18  young professional             166               26593            239
# 19  young professional             258               24243            121
# 2   young professional             261               33172            211
# 20  young professional             238               23044            119
# 21  young professional             234               23541            290
# 22  young professional             164               26806            178
# 23  young professional             345               25472            167
# 24  young professional             222               27967            292
# 25  young professional             289               24110            272
# 26  young professional             291               21274            279
# 27  young professional             222               27307            187
# 28  young professional             305               23945            215
# 29  young professional             264               28048            150
# 3   young professional             282               18257            230
# 30  young professional             346               22728            259
# 31  young professional             272               22085            106
# 32  young professional             159               30298            197
# 33  young professional             159               28095            224
# 34  young professional             177               20959            283
# 35  young professional             158               23812            125
# ..                 ...             ...                 ...            ...
# 72  young professional             152               22250            297
# 73  young professional             165               21632            275
# 74  young professional             163               28663            219
# 75  young professional             281               30931            134
# 76  young professional             280               21867            281
# 77  young professional             173               25546            160
# 78  young professional             338               24011            158
# 79  young professional             282               24309            153
# 8   young professional             346               18002            273
# 80  young professional             235               19286            100
# 81  young professional             186               23683            109
# 82  young professional             179               23255            181
# 83  young professional             193               32209            236
# 84  young professional             347               29024            260
# 85  young professional             330               28002            284
# 86  young professional             329               26740            285
# 87  young professional             225               28079            102
# 88  young professional             166               19883            111
# 89  young professional             308               22951            217
# 9   young professional             226               28765            170
# 90  young professional             284               20007            102
# 91  young professional             256               27520            107
# 92  young professional             244               31423            230
# 93  young professional             295               23225            206
# 94  young professional             162               19616            220
# 95  young professional             187               27400            283
